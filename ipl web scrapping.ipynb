# %%
import sys
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
try:

  page=requests.get("https://www.amazon.in/Apple-iPhone-Pro-Max-64GB/dp/B07XVL4L3X/ref=sr_1_1?crid=1XEAEXTQG9IPD&dchild=1&keywords=apple%2Biphone%2B11%2Bpro%2B256gb%2B")

except Exception as e:
  error_type,error_obj,error_info=sys.exc_info()
  print('ERROR OR LINK:',url)
  print(error_type,'Link:',error_info.tb_lineno)

time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('span',attrs={'class':'a-size-base'})

# %%
page
# Out:
# <Response [503]>

# %%
soup
# Out:
# <html>
# <head>
# <title>503 - Service Unavailable Error</title>
# </head>
# <body bgcolor="#FFFFFF" text="#000000">
# <!--
#         To discuss automated access to Amazon data please contact api-services-support@amazon.com.
#         For information about migrating to our APIs refer to our Marketplace APIs at https://developer.amazonservices.in/ref=rm_5_sv, or our Product Advertising API at https://affiliate-program.amazon.in/gp/advertising/api/detail/main.html/ref=rm_5_ac for advertising use cases.
# -->
# <center>
# <a href="https://www.amazon.in/ref=cs_503_logo/">
# <img alt="Amazon.in" border="0" height="45" src="https://images-eu.ssl-images-amazon.com/images/G/31/x-locale/communities/people/logo.gif" width="200"/></a>
# <p align="center">
# <font face="Verdana,Arial,Helvetica">
# <font color="#CC6600" size="+2"><b>Oops!</b></font><br/>
# ...

# %%
links
# Out:
# []

# %%
for i in links:
  print(i.text)
  print('\n')

# %%
try:

  page=requests.get('https://www.cricbuzz.com/cricket-series/3472/indian-premier-league-2021/stats')

except Exception as e:
    error_type,error_obj,error_info=sys.exc_info()
    print('ERROR FOR LINK:',URL)
    print(error_type,'Link:',error_info.tb_lineno)

time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('tr',attrs={'class':'cb-srs-stats-tr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<tr class="cb-srs-stats-tr"> <th class="cb-srs-stats-th cb-srs-stats-player text-right">POS</th> <th class="cb-srs-stats-th cb-srs-stats-player text-left">PLAYER</th> <th class="cb-srs-stats-th cb-srs-stats-player text-right">MATCHES</th> <th class="cb-srs-stats-th cb-srs-stats-player text-right">INNS</th> <th class="cb-srs-stats-th cb-srs-stats-player text-right">RUNS</th> <th class="cb-srs-stats-th cb-srs-stats-player text-right">AVG</th> <th class="cb-srs-stats-th cb-srs-stats-player text-right">SR</th> <th class="cb-srs-stats-th cb-srs-stats-player text-right">4s</th> <th class="cb-srs-stats-th cb-srs-stats-player text-right">6s</th> </tr>,
# ...

# %%
for i in links:
  print(i.text)
  print('\n')
# Out:
#  POS PLAYER MATCHES INNS RUNS AVG SR 4s 6s
#
#
#  1 KL Rahul 13 13 626 62.60 138.80 48 30
#
#
#  2 Ruturaj Gaikwad 15 15 603 46.38 137.36 61 22
#
#
#  3 Shikhar Dhawan 15 15 551 39.36 127.55 62 14
#
#
#  4 Faf du Plessis 15 15 547 42.08 137.09 53 20
#
#
#  5 Glenn Maxwell 14 13 498 45.27 147.34 47 21
#
#
#  6 Sanju Samson 14 14 484 40.33 136.72 45 17
#
#
#  7 Prithvi Shaw 14 14 461 32.93 159.52 54 17
#
#
#  8 Mayank Agarwal 12 12 441 40.09 140.45 42 18
#
#
#  9 Rishabh Pant 15 15 413 37.55 129.06 41 10
#
#
#  10 Devdutt Padikkal 13 13 390 32.50 125.81 42 14
#
#
#  11 Rohit Sharma 13 13 381 29.31 127.42 33 14
#
#
#  12 Rahul Tripathi 14 13 377 31.42 142.80 40 10
#
#
#  13 Virat Kohli 14 14 366 28.15 119.61 38 9
#
#
#  14 Shubman Gill 14 14 352 25.14 119.32 39 11
#
#
#  15 Nitish Rana 14 13 347 34.70 125.72 33 15

# %%
df=pd.DataFrame(links)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py:305: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   values = np.array([convert(v) for v in values])

# %%
import numpy as np

# %%
df.head()
# Out:
#    0  ...                                                  5
# 0     ...  [ , [Home],  , [Schedule & Results],  , [News]...
#
# [1 rows x 6 columns]

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=19, step=1)

# %%
df.tail()
# Out:
#    0     1  2                   3  4     5   ...        13 14    15 16    17 18
# 11     [11]       [[Rohit Sharma]]     [13]  ...  [127.42]     [33]     [14]
# 12     [12]     [[Rahul Tripathi]]     [14]  ...  [142.80]     [40]     [10]
# 13     [13]        [[Virat Kohli]]     [14]  ...  [119.61]     [38]      [9]
# 14     [14]       [[Shubman Gill]]     [14]  ...  [119.32]     [39]     [11]
# 15     [15]        [[Nitish Rana]]     [14]  ...  [125.72]     [33]     [15]
#
# [5 rows x 19 columns]

# %%
try:

  page=requests.get('https://www.cricbuzz.com/cricket-series/3472/indian-premier-league-2021/stats')

except Exception as e:
    error_type,error_obj,error_info=sys.exc_info()
    print('ERROR FOR LINK:',URL)
    print(error_type,'Link:',error_info.tb_lineno)

time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-col-100 cb-col cb-nav-main cb-bg-white'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<div class="cb-col-100 cb-col cb-nav-main cb-bg-white"> <h1 class="cb-nav-hdr cb-font-24 line-ht30">Indian Premier League 2021</h1> <div class="text-gray"> <span> 62 T20s </span> <span class="cb-nav-dt"> . </span> <span>Apr 09</span> <span> - Oct 15</span> </div> <nav class="cb-nav-bar" role="navigation"> <a class="cb-nav-tab" href="/cricket-series/3472/indian-premier-league-2021" ng-class="{'series-index':'active', 'series-hotlink':'active'}[PAGE_NAME]" target="_self" title="IPL 2021 Home">Home</a> <a class="cb-nav-tab" href="/cricket-series/3472/indian-premier-league-2021/matches" ng-class="{'series-matches':'active','series-review-matches':'active'}[PAGE_NAME]" target="_self" title="IPL 2021 Schedule and Results">Schedule &amp; Results</a> <a class="cb-nav-tab" href="/cricket-series/3472/indian-premier-league-2021/news" ng-class="{'series-news':'active','news-detail':'active'}[PAGE_NAME]" target="_self" title="IPL 2021 News">News</a> <a class="cb-nav-tab" href="/cricket-series/34
# ...

# %%
for i in links:
  print(i.text)
  print('\n')
# Out:
#  Indian Premier League 2021   62 T20s   .  Apr 09  - Oct 15   Home Schedule & Results News Videos Points Table Squads  Specials   2021 IPL Timeline Wickets Zone Boundary Tracker History   Photos Stats Venues

# %%
df2= pd.DataFrame(links)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py:305: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   values = np.array([convert(v) for v in values])

# %%
import numpy as np

# %%
df2.head()
# Out:
#    0  ...                                                  5
# 0     ...  [ , [Home],  , [Schedule & Results],  , [News]...
#
# [1 rows x 6 columns]

# %%
df2.tail()
# Out:
#    0  ...                                                  5
# 0     ...  [ , [Home],  , [Schedule & Results],  , [News]...
#
# [1 rows x 6 columns]

# %%
df
# Out:
#    0      1  2                     3  4   ... 14    15 16    17 18
# 0      [POS]                 [PLAYER]     ...     [4s]     [6s]
# 1        [1]             [[KL Rahul]]     ...     [48]     [30]
# 2        [2]      [[Ruturaj Gaikwad]]     ...     [61]     [22]
# 3        [3]       [[Shikhar Dhawan]]     ...     [62]     [14]
# 4        [4]       [[Faf du Plessis]]     ...     [53]     [20]
# 5        [5]        [[Glenn Maxwell]]     ...     [47]     [21]
# 6        [6]         [[Sanju Samson]]     ...     [45]     [17]
# 7        [7]         [[Prithvi Shaw]]     ...     [54]     [17]
# 8        [8]       [[Mayank Agarwal]]     ...     [42]     [18]
# 9        [9]         [[Rishabh Pant]]     ...     [41]     [10]
# 10      [10]     [[Devdutt Padikkal]]     ...     [42]     [14]
# 11      [11]         [[Rohit Sharma]]     ...     [33]     [14]
# 12      [12]       [[Rahul Tripathi]]     ...     [40]     [10]
# 13      [13]          [[Virat Kohli]]     ...     [38]      [9]
# ...
